# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
import os

load_dotenv()

os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# %%
model = ChatGoogleGenerativeAI(model="gemini-3.6-flash")
model
# Out:
# ChatGoogleGenerativeAI(metadata={'lc_versions': {'langchain-core': '1.6.3', 'langchain': '1.4.1', 'langchain-google-genai': '4.4.0'}}, profile={'name': 'Gemini 3.6 Flash', 'release_date': '2026-07-21', 'last_updated': '2026-07-21', 'open_weights': False, 'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True, 'reasoning_effort_levels': ['minimal', 'low', 'medium', 'high'], 'reasoning_effort_default': 'medium'}, google_api_key=SecretStr('**********'), model='gemini-3.6-flash', temperature=None, client=<google.genai.client.Client object at 0x000002DCC3A8B750>, default_metadata=(), model_kwargs={})

# %%
for chunk in model.stream("Tell me about Agentic AI in 20 words"): 
    print(chunk.text)
# Out:
# Agentic AI consists of autonomous systems capable of reasoning
# , planning, making decisions, and executing complex tasks independently to achieve specific goals.

# %% [markdown]
# ### Batching

# %%
responses = model.batch([
    "Tell me about Agentic AI in 20 words",
    "What are RAGs?"
])

for response in responses: 
    print(response)
# Out:
# content=[{'type': 'text', 'text': 'Agentic AI refers to autonomous systems that independently reason, plan, use tools, and execute actions to achieve complex user goals.', 'extras': {'signature': '...'}}] additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.6-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--01a0c2a3-9f9b-7f71-8fcb-260b39e55432-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 12, 'output_tokens': 513, 'total_tokens': 525, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 488}}
# content=[{'type': 'text', 'text': 'In the context of Artificial Intelligence, **RAG** stands for **Retrieval-Augmented Generation**. \n\nIt is a technique used to improve the accuracy and reliability of Large Language Models (LLMs) like ChatGPT by connecting them to external databases or documents.\n\n---\n\n### The Analogy: Closed-Book vs. Open-Book Exam\n\nTo understand RAG, imagine taking a test:\n* **Standard LLM (Closed-Book Exam):** The AI relies purely on what it learned during its initial training. If asked a question about a company\'s internal policy or events from yesterday, it might guess, give outdated information, or completely make things up (called **hallucination**).\n* **RAG-enabled LLM (Open-Book Exam):** Before answering, the AI looks up relevant documents in a customized library, reads them, and then uses that specific information to answer the question accurately.\n\n---\n\n### Why do we need RAG?\n\nStandard AI models have three major limitations:\n1. **Outdated Knowledge:** LLMs are trained at a specific point in time and don\'t know current events.\n2. **Hallucinations:** When an LLM doesn\'t know an answer, it often speaks with confidence even if it is wrong.\n3. **No Access to Private Data:** An LLM doesn\'t know your company’s internal files, personal notes, or proprietary code.\n\n**RAG solves all three issues** without requiring you to re-train the AI model (which is extremely expensive and time-consuming).\n\n---\n\n### How RAG Works (Step-by-Step)\n\n1. **User asks a question:**  \n   *Example:* "What is our company\'s remote work policy regarding work outside the country?"\n\n2. **Retrieval (Finding the facts):**  \n   The RAG system searches a private database (e.g., your company’s PDF handbooks, Google Drive, or Notion pages) for documents related to "remote work" and "outside the country."\n\n3. **Augmentation (Combining question + context):**  \n   The system creates a new, enriched prompt for the AI model.  \n   *Prompt sent to AI:* "Using the following company policy excerpt: [Inserted Text from Handbook], please answer this user question: What is our remote work policy regarding work outside the country?"\n\n4. **Generation (Writing the answer):**  \n   The LLM reads the retrieved text and generates a clear, accurate, and up-to-date answer based *only* on that text.\n\n---\n\n### Key Benefits of RAG\n\n* **High Accuracy:** Significantly reduces false or fabricated information (hallucinations).\n* **Sources and Citations:** RAG systems can show you the exact document or page link used to generate the answer.\n* **Data Security & Control:** Keeps private data secure. You control what documents the AI can access.\n* **Cost-Effective:** Updating the external database takes seconds and costs almost nothing, whereas re-training an AI model costs millions of dollars.\n\n---\n\n### Common Use Cases\n\n* **Enterprise Chatbots:** Allowing employees to ask questions about internal HR policies, IT troubleshooting, or product documentation.\n* **Customer Support:** Chatbots that pull answers directly from live support articles and knowledge bases.\n* **Legal and Medical Research:** AI tools that analyze specific legal briefs or medical journals to answer complex queries with sources.', 'extras': {'signature': '...'}}] additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.6-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--01a0c2a3-9f9e-7dc1-8da5-d6cdba6f4c67-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 7, 'output_tokens': 1512, 'total_tokens': 1519, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 791}}
